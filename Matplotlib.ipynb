# %% [markdown]
# <a href="https://colab.research.google.com/github/sks95/python_basics/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
#plt.style.use("fivethirtyeight")

# %% [markdown]
# ## Line Chart

# %%
x = [10, 20, 30]
y = [20, 40, 30]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
country = ["India", "US", "UK", "Ukraine", "Russia"]
male = [87, 45, 76, 23, 35]
female = [12, 32, 25, 32, 21]

# %%
plt.bar(country,male)
plt.xlabel("Country")
plt.ylabel("Male")
plt.title("Populations")
# Out:
# Text(0.5, 1.0, 'Populations')

# %%
plt.bar(country,male,width=0.4,color="orange")
plt.xlabel("Country")
plt.ylabel("Male")
plt.title("Populations")
# Out:
# Text(0.5, 1.0, 'Populations')

# %%
plt.bar(country, male)
plt.bar(country, female, width = 0.4)
plt.xlabel("Country")
plt.ylabel("Male")
plt.title("Populations")
# Out:
# Text(0.5, 1.0, 'Populations')

# %%
plt.bar(country,male, width=0.5)
plt.bar(country, female, width=0.5,align="edge")
plt.xlabel("Country")
plt.ylabel("Male")
plt.title("Populations")
# Out:
# Text(0.5, 1.0, 'Populations')

# %%
plt.bar(country,male, label="male")
plt.bar(country,female,bottom=male, label="female")
plt.xlabel("Country")
plt.ylabel("Gender")
plt.title("Population")
plt.legend(shadow=True, facecolor="white", frameon=True)

# %% [markdown]
# ## Histogram

# %%
import numpy as np
np.random.seed(42)
num = np.random.randn(100)

# %%
plt.hist(num, color="orange")
# Out:
# (array([ 1.,  4.,  6.,  8., 19., 17., 21., 11.,  6.,  7.]),
#  array([-2.6197451 , -2.17254278, -1.72534045, -1.27813812, -0.83093579,
#         -0.38373346,  0.06346887,  0.5106712 ,  0.95787353,  1.40507586,
#          1.85227818]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(num, color="orange",bins=10)
# Out:
# (array([ 1.,  4.,  6.,  8., 19., 17., 21., 11.,  6.,  7.]),
#  array([-2.6197451 , -2.17254278, -1.72534045, -1.27813812, -0.83093579,
#         -0.38373346,  0.06346887,  0.5106712 ,  0.95787353,  1.40507586,
#          1.85227818]),
#  <a list of 10 Patch objects>)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/purna135/ML-Datasets/main/iris.csv")
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
plt.hist(df['sepal.length'], alpha=0.5, label="Sepal Length")
plt.hist(df['petal.length'], alpha=0.5, label="Petal Length")
plt.legend(shadow=True, facecolor="white", frameon=True)

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(df['sepal.length'], df['sepal.width'], marker='*')
plt.scatter(df['petal.length'], df['petal.width'], marker='d')

# %% [markdown]
# ## Pie Chart

# %%
plt.pie(male, labels=country)
plt.show()

# %%
plt.pie(male, labels = country, autopct = "%1.1f%%", shadow=True, explode = [0.2, 0, 0, 0, 0])
plt.show()

# %% [markdown]
# ## Subplot

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.hist(df['sepal.width'])

plt.subplot(1,2,2)
plt.hist(df['petal.width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <a list of 10 Patch objects>)
